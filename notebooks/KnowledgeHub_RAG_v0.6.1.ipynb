# %% [markdown]
# # KnowledgeHub RAG v0.6.1 – Conversational Retrieval-Augmented Generation
#
# ## Objective
#
# The objective of v0.6.1 is to extend the Retrieval-Augmented Generation (RAG) system with conversational capabilities while improving the stability and reliability of answer generation.
#
# Building upon the hybrid retrieval pipeline introduced in v0.6, this release introduces conversation memory, enabling the system to understand follow-up questions by retaining relevant context from previous interactions. The answer generation pipeline has also been refined through improved prompting and generation configuration, resulting in cleaner, more context-grounded responses.
#
# ## New Features
#
# - Introduces conversational memory for multi-turn question answering.
# - Supports follow-up questions without requiring users to repeat previous context.
# - Retains relevant conversation history to improve contextual understanding.
# - Refines TinyLlama prompting for more concise, grounded responses.
# - Improves generation stability through updated model configuration.
# - Maintains the enhanced hybrid retrieval pipeline introduced in v0.6:
#   - Semantic Search (FAISS)
#   - BM25 Retrieval
#   - Query Expansion
#   - Weighted Score Fusion
#   - Reciprocal Rank Fusion (RRF)
#   - Context Expansion
#
# ## Workflow
#
# User Question
# ↓
# Conversation Memory
# ↓
# Query Expansion
# ↓
# Semantic Search (FAISS) + BM25 Retrieval
# ↓
# Weighted Score Fusion
# ↓
# Reciprocal Rank Fusion (RRF)
# ↓
# Context Expansion
# ↓
# TinyLlama LLM
# ↓
# Context-Grounded Conversational Answer
#
# ## Learning Objectives
#
# - Understand conversational Retrieval-Augmented Generation (RAG) systems.
# - Maintain conversational context across multiple user interactions.
# - Combine conversation memory with hybrid retrieval techniques.
# - Generate grounded answers using retrieved document context and prior conversation.
# - Improve answer quality through prompt engineering and generation tuning.
#
# ## Version Highlights
#
# - Conversational memory
# - Multi-turn question answering
# - Hybrid retrieval (FAISS + BM25)
# - Query expansion
# - Weighted score fusion
# - Reciprocal Rank Fusion (RRF)
# - Context expansion
# - TinyLlama-powered answer generation
# - Context-grounded conversational responses
# - Interactive document question-answering interface
#
# ## Known Limitations
#
# - TinyLlama (1.1B) may occasionally introduce unsupported details when summarising long contexts.
# - Responses remain dependent on the quality of retrieved document chunks.
# - Future releases will evaluate stronger open-source language models and introduce automated answer verification to further reduce hallucinations.

# %%
# !pip install -q sentence-transformers
# !pip install -q faiss-cpu
# !pip install -q pypdf
# !pip install -q transformers
# !pip install -q accelerate
# !pip install -q rank-bm25
# !pip install -q langchain
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 26.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.1/378.1 kB 5.3 MB/s eta 0:00:00

# %%
import os
import time
import faiss
import numpy as np

from pypdf import PdfReader

from sentence_transformers import SentenceTransformer

from transformers import pipeline

from rank_bm25 import BM25Okapi

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

DATA_PATH = "/content/drive/MyDrive/KnowledgeHub_RAG/data"

pdf_files = [
    os.path.join(DATA_PATH, file)
    for file in os.listdir(DATA_PATH)
    if file.lower().endswith(".pdf")
]

print(f"Found {len(pdf_files)} PDF(s):")

for pdf in pdf_files:
    print("-", os.path.basename(pdf))
# Out:
# Found 1 PDF(s):
# - Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf

# %%
def load_pdf(pdf_path):

    reader = PdfReader(pdf_path)

    pages = []

    for page_number, page in enumerate(reader.pages, start=1):

        extracted = page.extract_text()

        if extracted:

            pages.append(
                {
                    "page": page_number,
                    "text": extracted
                }
            )

    return pages


documents = []

for pdf in pdf_files:

    pages = load_pdf(pdf)

    documents.append(
        {
            "filename": os.path.basename(pdf),
            "pages": pages
        }
    )

print(f"Loaded {len(documents)} document(s).")
# Out:
# Loaded 1 document(s).

# %%
# !pip install -q langchain-text-splitters

# %%
import re

from langchain_text_splitters import RecursiveCharacterTextSplitter


# ==========================================================
# Heading Detection
# ==========================================================

def is_heading(line):

    line = line.strip()

    if len(line) < 2:
        return False

    # 1
    # 1.2
    # 2.3.4
    if re.match(r"^\d+(\.\d+)*\s+[A-Z]", line):
        return True

    # ALL CAPS
    if line.isupper() and len(line.split()) <= 8:
        return True

    # Markdown
    if line.startswith("#"):
        return True

    # Very short title
    if len(line.split()) <= 8 and line.endswith(":"):
        return True

    return False


# ==========================================================
# Split page into sections using headings
# ==========================================================

def split_into_sections(text):

    lines = text.split("\n")

    sections = []

    current = []

    for line in lines:

        if is_heading(line):

            if current:
                sections.append("\n".join(current).strip())

            current = [line]

        else:

            current.append(line)

    if current:
        sections.append("\n".join(current).strip())

    return sections


# ==========================================================
# Recursive splitter
# ==========================================================

splitter = RecursiveCharacterTextSplitter(

    chunk_size=800,

    chunk_overlap=150,

    separators=[
        "\n\n",
        "\n",
        ". ",
        " ",
        ""
    ]
)


# ==========================================================
# Final Chunking Function
# ==========================================================

def chunk_text(text):

    sections = split_into_sections(text)

    final_chunks = []

    for section in sections:

        if len(section) <= 900:

            final_chunks.append(section)

        else:

            final_chunks.extend(
                splitter.split_text(section)
            )

    return final_chunks

# %%
all_chunks = []

chunk_id = 0

for document in documents:

    for page in document["pages"]:

        sections = split_into_sections(page["text"])

        for section in sections:

            # -----------------------------
            # Extract heading
            # -----------------------------
            lines = section.split("\n")

            heading = ""

            if lines and is_heading(lines[0]):
                heading = lines[0].strip()

            # -----------------------------
            # Split section if needed
            # -----------------------------
            if len(section) <= 900:

                section_chunks = [section]

            else:

                section_chunks = splitter.split_text(section)

            # -----------------------------
            # Save chunks
            # -----------------------------
            for chunk in section_chunks:

                all_chunks.append(
                    {
                        "chunk_id": chunk_id,
                        "document": document["filename"],
                        "page": page["page"],
                        "section": heading,
                        "text": chunk
                    }
                )

                chunk_id += 1

print(f"Created {len(all_chunks)} chunks.")
# Out:
# Created 112 chunks.

# %%
print("=" * 80)

print("FIRST 10 CHUNKS")

print("=" * 80)

for chunk in all_chunks[:10]:

    print(f"\nChunk ID : {chunk['chunk_id']}")

    print(f"Page     : {chunk['page']}")


    print("-" * 80)

    print(chunk["text"][:400])

    print()
# Out:
# ================================================================================
# FIRST 10 CHUNKS
# ================================================================================
#
# Chunk ID : 0
# Page     : 1
# --------------------------------------------------------------------------------
# Machine Learning Classification of Binary Neutron
# Star Remnants Using Gravitational Wave Data
# Surendaranath Kanniyappan
# Dr. Michalis Agathos
# Abstract
# Binary neutron star (BNS) mergers are among the most energetic cosmic events,
# producing gravitational waves (GWs), electromagnetic (EM) counterparts, and potentially
# neutrinos. These mergers provide an unparalleled opportunity to study supranuclear m
#
#
# Chunk ID : 1
# Page     : 1
# --------------------------------------------------------------------------------
# hypermassive neutron star (short- or long-lived HMNS), or remains stable.
# Direct detection of postmerger GW signals remains challenging due to their high
# frequency nature (≳ 1 kHz) and the sensitivity limits of current interferometers. Therefore,
# predicting remnant outcomes from inspiral parameters—total mass Mtot, mass ratio q, tidal
# deformability ˜Λ, and effective spin χeff, is essential to enab
#
#
# Chunk ID : 2
# Page     : 1
# --------------------------------------------------------------------------------
# neutron star remnant), three-class (PCBH vs HMNS vs stable NS), and four-class (PCBH vs
# short-lived HMNS vs long-lived HMNS vs stable NS). Model performance is evaluated on
# simulated datasets and applied to real GW events (GW170817, GW190425), with calibrated
# probability outputs and entropy-based uncertainty measures for low-confidence predictions.
# 1
#
#
# Chunk ID : 3
# Page     : 2
# --------------------------------------------------------------------------------
# 1 Introduction
# Binary neutron star (BNS) mergers are among the most extreme events in the Universe, acting as
# unique laboratories for probing matter at supranuclear densities and constraining the neutron-star
# equation of state (EoS) [ 1, 2, 3]. The outcome of such mergers depends sensitively on the
# properties of the progenitor stars and the physics governing dense matter. Postmerger remnants
# may u
#
#
# Chunk ID : 4
# Page     : 2
# --------------------------------------------------------------------------------
# electromagnetic (EM) counterparts, nucleosynthesis yields, and the long term evolution of the
# system.
# The classification of postmerger remnants can be guided by parameters inferred from the
# inspiral phase of the GW signal, when the signal-to-noise ratio (SNR) is typically highest. The
# key among these are the total gravitational mass of the system ( Mtot), the mass ratio (q), the
# mass weighted tida
#
#
# Chunk ID : 5
# Page     : 2
# --------------------------------------------------------------------------------
# Direct detection of postmerger GW emission remains a formidable challenge. The dominant
# spectral power lies in the kilohertz regime above ≳ 1 kHz,where the sensitivity of the Advanced
# LIGO, Virgo, and KAGRA detectors drops steeply [6, 7]. Without robust access to this phase of
# the signal, observational strategies must rely on low latency inference from inspiral parameters
# to guide EM follow up cam
#
#
# Chunk ID : 6
# Page     : 2
# --------------------------------------------------------------------------------
# physics [ 14, 15]. It demonstrated the feasibility of joint GW EM observations, confirmed BNS
# mergers as a site of r-process nucleosynthesis [19], and placed constraints on ˜Λ that favour
# relatively soft EoSs. The detection of GW190425 [ 16], despite lacking an EM counterpart,
# expanded the observed parameter space toward higher total masses and possibly more compact
# configurations.
# Building on thi
#
#
# Chunk ID : 7
# Page     : 2
# --------------------------------------------------------------------------------
# and SACRA [13]. Their work demonstrates that inspiral phase parameters alone can provide
# probabilistic forecasts of the remnant type, enabling low-latency decision making in GW alert
# pipelines. This study adopts, reproduces, and extends that methodology, integrating lessons
# from ML best practices [20] and targeting robust application to both simulated and real GW
# events.
# 2
#
#
# Chunk ID : 8
# Page     : 3
# --------------------------------------------------------------------------------
# 2 Literature Review
#
#
# Chunk ID : 9
# Page     : 3
# --------------------------------------------------------------------------------
# 2.1 Machine learning remnant classifier (Puecher & Dietrich)
# The study by Puecher & Dietrich [11] forms the methodological backbone of this work. Their
# approach employs GBDT models to classify postmerger remnants using only inspiral parameters
# derived from NR simulations. They define three taxonomies: binary (PCBH vs. any neutron
# star remnant), three class (PCBH vs. HMNS vs. stable/no collapse), a

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer(
    "sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
texts = [chunk["text"] for chunk in all_chunks]

embeddings = embedding_model.encode(
    texts,
    normalize_embeddings=True,
    show_progress_bar=True
)

print(embeddings.shape)
# Out:
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# (112, 384)

# %%
import faiss

dimension = embeddings.shape[1]

index = faiss.IndexFlatIP(dimension)

index.add(
    embeddings.astype("float32")
)

print(index.ntotal)
# Out:
# 112

# %%
tokenized_corpus = [
    chunk["text"].lower().split()
    for chunk in all_chunks
]

bm25 = BM25Okapi(tokenized_corpus)

print(" BM25 Index Built")
# Out:
#  BM25 Index Built

# %%
QUERY_EXPANSION = {

    "algorithm": [
        "model",
        "classifier",
        "GBDT",
        "Gradient Boosted Decision Tree"
    ],

    "gbdt": [
        "Gradient Boosted Decision Tree",
        "gradient boosting"
    ],

    "classifier": [
        "classification model",
        "machine learning model"
    ],

    "accuracy": [
        "performance",
        "evaluation",
        "MCC"
    ],

    "dataset": [
        "training data",
        "simulation dataset"
    ],

    "method": [
        "approach",
        "framework"
    ]
}


def expand_query(query):

    expanded = query

    query_lower = query.lower()

    for key, values in QUERY_EXPANSION.items():

        if key in query_lower:

            expanded += " " + " ".join(values)

    return expanded

# %%
def reciprocal_rank_fusion(semantic_results, bm25_results, k=60):
    """
    Reciprocal Rank Fusion (RRF)

    Score(doc) = Σ 1 / (k + rank)

    Larger k -> smoother scores (60 is the standard value).
    """

    fused = {}

    # Semantic ranking
    for rank, item in enumerate(semantic_results, start=1):
        cid = item["chunk_id"]

        if cid not in fused:
            fused[cid] = item.copy()
            fused[cid]["rrf_score"] = 0.0

        fused[cid]["rrf_score"] += 1.0 / (k + rank)

    # BM25 ranking
    for rank, item in enumerate(bm25_results, start=1):
        cid = item["chunk_id"]

        if cid not in fused:
            fused[cid] = item.copy()
            fused[cid]["rrf_score"] = 0.0

        fused[cid]["rrf_score"] += 1.0 / (k + rank)

    return sorted(
        fused.values(),
        key=lambda x: x["rrf_score"],
        reverse=True
    )

# %%
def retrieve(query, top_k=5):

    # =====================================================
    # Encode Query
    # =====================================================
    expanded_query = expand_query(query)

    query_embedding = embedding_model.encode(
        [expanded_query],
        normalize_embeddings=True
    ).astype("float32")

    # =====================================================
    # FAISS Search
    # =====================================================

    semantic_scores, semantic_indices = index.search(
        query_embedding,
        top_k * 8
    )

    semantic_results = []

    for rank, (score, idx) in enumerate(
        zip(semantic_scores[0], semantic_indices[0]),
        start=1
    ):

        semantic_results.append({

            "chunk_id": idx,
            "rank": rank,
            "semantic_score": float(score)

        })

    # =====================================================
    # BM25 Search
    # =====================================================

    tokenized_query = expanded_query.lower().split()

    bm25_scores = bm25.get_scores(tokenized_query)

    bm25_ranked = sorted(

        enumerate(bm25_scores),

        key=lambda x: x[1],

        reverse=True

    )[:top_k * 8]

    bm25_results = []

    for rank, (idx, score) in enumerate(
        bm25_ranked,
        start=1
    ):

        bm25_results.append({

            "chunk_id": idx,
            "rank": rank,
            "bm25_score": float(score)

        })

    # =====================================================
    # Reciprocal Rank Fusion (RRF)
    # =====================================================

    k = 60

    rrf_scores = {}

    semantic_lookup = {}
    bm25_lookup = {}

    for item in semantic_results:

        cid = item["chunk_id"]

        semantic_lookup[cid] = item["semantic_score"]

        rrf_scores[cid] = rrf_scores.get(cid, 0) + 1 / (k + item["rank"])

    for item in bm25_results:

        cid = item["chunk_id"]

        bm25_lookup[cid] = item["bm25_score"]

        rrf_scores[cid] = rrf_scores.get(cid, 0) + 1 / (k + item["rank"])

    rrf_results = []

    for chunk_id, rrf_score in rrf_scores.items():

        chunk = all_chunks[chunk_id]

        rrf_results.append({

            "chunk_id": chunk_id,

            "page": chunk["page"],

            "document": chunk["document"],

            "text": chunk["text"],

            "semantic_score": semantic_lookup.get(chunk_id, 0.0),

            "bm25_score": bm25_lookup.get(chunk_id, 0.0),

            "rrf_score": rrf_score

        })

    # =====================================================
    # Intelligent Tie Breaking
    # =====================================================

    for item in rrf_results:

        item["final_score"] = (

            item["rrf_score"]

            + 0.001 * item["semantic_score"]

            + 0.001 * item["bm25_score"]

        )

    rrf_results = sorted(

        rrf_results,

        key=lambda x: x["final_score"],

        reverse=True

    )

    # =====================================================
    # Prevent Adjacent Matched Chunks
    # =====================================================

    selected = []

    for item in rrf_results:

        current = item["chunk_id"]

        if any(abs(current - x["chunk_id"]) <= 1 for x in selected):
            continue

        selected.append(item)

        if len(selected) == top_k:
            break

    # =====================================================
    # Context Expansion
    # =====================================================

    expanded = []

    visited = set()

    for rank, item in enumerate(selected, start=1):

        current = item["chunk_id"]

        for neighbour in [current - 1, current, current + 1]:

            if neighbour < 0:
                continue

            if neighbour >= len(all_chunks):
                continue

            if neighbour in visited:
                continue

            if all_chunks[neighbour]["document"] != item["document"]:
                continue

            visited.add(neighbour)

            chunk = all_chunks[neighbour]

            expanded.append({

                "chunk_id": chunk["chunk_id"],

                "page": chunk["page"],

                "document": chunk["document"],

                "text": chunk["text"],

                "retrieval_rank": rank,

                "context_neighbor": neighbour != current,

                "semantic_score": item["semantic_score"] if neighbour == current else None,

                "bm25_score": item["bm25_score"] if neighbour == current else None,

                "rrf_score": item["rrf_score"] if neighbour == current else None

            })

    return expanded

# %%
def debug_retrieval(query, top_k=5):

    results = retrieve(query, top_k)

    print("=" * 90)
    print(f"QUERY : {query}")
    print("=" * 90)

    current_rank = None

    for chunk in results:

        if chunk["retrieval_rank"] != current_rank:

            current_rank = chunk["retrieval_rank"]

            print()
            print("=" * 90)
            print(f"RETRIEVAL RANK {current_rank}")
            print("=" * 90)

        print()

        if chunk["context_neighbor"]:

            print("Context Chunk")

        else:

            print("Matched Chunk")

            print(f"Semantic Score : {chunk['semantic_score']:.4f}")
            print(f"BM25 Score     : {chunk['bm25_score']:.4f}")
            if "rrf_score" in chunk:
              print(f"RRF Score      : {chunk['rrf_score']:.5f}")

        print(f"Document : {chunk['document']}")
        print(f"Page     : {chunk['page']}")

        if chunk.get("section"):
          print(f"Section  : {chunk['section']}")

        print(f"Chunk ID : {chunk['chunk_id']}")

        print("-" * 90)

        print(chunk["text"][:700])

        print()

# %%
debug_retrieval("What algorithm was used for classification?")

debug_retrieval("What is GBDT?")

debug_retrieval("Gradient Boosted Decision Tree")
# Out:
# ==========================================================================================
# QUERY : What algorithm was used for classification?
# ==========================================================================================
#
# ==========================================================================================
# RETRIEVAL RANK 1
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 8
# Chunk ID : 33
# ------------------------------------------------------------------------------------------
# difficulty-aware splitting strategy described in [11] is adopted:
# 1. Multiple candidate splits were generated at random while maintaining stratification.
# 2. Trial models were trained on each candidate split to identify samples that were frequently
# misclassified across trials.
# 3. Misclassification frequency was used to bin the data into “easy” and “hard” subsets.
# 4. Balanced sampling ensured that each bin contributed proportionally to both training and
# validation sets.
# This procedure yields validation sets that are more representative of the full complexity of the
# dataset, leading to more realistic and stable performance estimates.
#
#
# Matched Chunk
# Semantic Score : 0.6347
# BM25 Score     : 13.7764
# RRF Score      : 0.03279
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 8
# Chunk ID : 34
# ------------------------------------------------------------------------------------------
# 3.5 Gradient Boosted Decision Tree (GBDT) Training
# All three classifiers were trained using the gradient boosting framework for decision trees [27]
# as implemented in scikit-learn [28]. This method builds an ensemble of shallow decision
# trees (weak learners) sequentially, with each new tree correcting the residual errors of the
# previous ensemble. The outputs are combined, weighted by a learning rate, and refined over
# multiple boosting rounds to improve predictions.
# Key hyperparameters were tuned to balance complexity and generalisation:
# • Tree depth: kept shallow to mitigate overfitting on a limited dataset.
# • Learning rate: set for gradual convergence and stable improvements.
# • Number of est
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 8
# Chunk ID : 35
# ------------------------------------------------------------------------------------------
# GBDT was chosen because:
# (a) it captures complex, non-linear decision boundaries;
# (b) it performs well on moderate sized datasets without requiring vast training data;
# (c) it offers interpretable feature importance metrics, aiding astrophysical validation.
# 8
#
#
# ==========================================================================================
# RETRIEVAL RANK 2
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 19
# Chunk ID : 86
# ------------------------------------------------------------------------------------------
# quantification in real world deployment, as confidence estimates directly impact observational
# strategies. The methodology developed here could be extended to other compact binary systems,
# such as neutron star–black hole mergers, where prompt collapse likelihood is also a key
# determinant of EM detectability. In the context of upcoming third-generation GW detectors,
# this framework can serve as a foundation for rapid, physically interpretable, and operationally
# relevant classification tools, ensuring that the multi-messenger community can maximise science
# returns from every detected event.
# 19
#
#
# Matched Chunk
# Semantic Score : 0.4623
# BM25 Score     : 11.3846
# RRF Score      : 0.03105
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 20
# Chunk ID : 87
# ------------------------------------------------------------------------------------------
# 6 Conclusion
# The present work develops, implements, and rigorously validates a set of three Gradient Boosted
# Decision Tree (GBDT) classifiers designed to predict the post-merger remnant outcome of binary
# neutron star (BNS) mergers using only inspiral phase parameters namely the total gravitational
# mass Mtot, mass ratio q, effective tidal deformability ˜Λ, and effective spin parameter χeff. These
# parameters are obtainable from gravitational-wave (GW) observations during the inspiral phase,
# making the models suitable for low latency analysis before post-merger GW signals are detected.
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 20
# Chunk ID : 88
# ------------------------------------------------------------------------------------------
# The classifiers correspond to progressively finer-grained classification tasks:
# • Classifier A: Binary decision between prompt collapse to a black hole (PCBH) and the
# formation of any neutron-star (NS) remnant.
# • Classifier B: Three-way classification distinguishing PCBH, hypermassive neutron star
# (HMNS), and no collapse within the simulation window (NC).
# • Classifier C: Four-class classification further splitting HMNS into short-lived (2 ms <
# τBH < 5 ms) and long-lived (τBH > 5 ms) remnants.
# Training and validation utilised carefully curated numerical relativity (NR) simulation
# datasets spanning a wide range of equations of state (EoS), total masses, mass ratios, and
# spin configurations [12
#
#
# ==========================================================================================
# RETRIEVAL RANK 3
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 6
# Chunk ID : 21
# ------------------------------------------------------------------------------------------
# The inspiral parameters used as classifier inputs total massMtot, mass ratio q, mass-weighted
# tidal deformability ˜Λ, and effective inspiral spin χeff are chosen because they can be estimated
# from gravitational-wave (GW) observations of the inspiral phase alone, even in cases where the
# postmerger signal is too weak to detect [2]. This makes the approach suitable for low latency
# classification in real events.
#
#
# Matched Chunk
# Semantic Score : 0.4210
# BM25 Score     : 8.4302
# RRF Score      : 0.02988
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 6
# Chunk ID : 22
# ------------------------------------------------------------------------------------------
# Two simulation datasets were employed for training:
# • Dataset for Classifier A : Used to train a binary model that distinguishes between:
# (a) Prompt collapse to a black hole (PCBH).
# (b) Any neutron star (NS) remnant, which here includes short-lived hypermassive
# neutron stars (HMNS), long-lived HMNS, and remnants showing no collapse within
# the simulation time.
# • Dataset for Classifiers B and C : Used for multi-class classification with finer outcome
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 6
# Chunk ID : 23
# ------------------------------------------------------------------------------------------
# granularity:
#
#
# ==========================================================================================
# RETRIEVAL RANK 4
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 22
# Chunk ID : 101
# ------------------------------------------------------------------------------------------
# MX
# m=1
# p(y | x; θ(m))
# !
# − 1
# M
#
#
# Matched Chunk
# Semantic Score : 0.4175
# BM25 Score     : 6.9958
# RRF Score      : 0.02924
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 22
# Chunk ID : 102
# ------------------------------------------------------------------------------------------
# MX
# m=1
# H
#
# p(y | x; θ(m))
#
# . (2)
# To generate the model ensemble, stochastic gradient boosting with different random states is
# employed [27, 28]. For a point x in the validation set, larger values of the knowledge uncertainty
# U (x) indicate that the prediction is more likely to be a misclassification. A simple detector
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 22
# Chunk ID : 103
# ------------------------------------------------------------------------------------------
# compares U (x) against a threshold T :
# IT (x) =
# (
# 1, U (x) > T,
# 0, U (x) ≤ T. (3)
# By sweeping T and comparing to the known validation labels, one can build ROC and
# precision–recall curves to derive operating points with bounded false positive rate and near-unity
# true positive rate [34, 35]. Using a single (non-ensemble) model, thresholds TA ≈ 0.3, TB ≈ 0.06,
# and TC ≈ 0.09 provide conservative flags for high-uncertainty predictions in Classifiers A, B,
# and C, respectively.
# 22
#
#
# ==========================================================================================
# RETRIEVAL RANK 5
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 3
# Chunk ID : 8
# ------------------------------------------------------------------------------------------
# 2 Literature Review
#
#
# Matched Chunk
# Semantic Score : 0.4513
# BM25 Score     : 5.7902
# RRF Score      : 0.02963
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 3
# Chunk ID : 9
# ------------------------------------------------------------------------------------------
# 2.1 Machine learning remnant classifier (Puecher & Dietrich)
# The study by Puecher & Dietrich [11] forms the methodological backbone of this work. Their
# approach employs GBDT models to classify postmerger remnants using only inspiral parameters
# derived from NR simulations. They define three taxonomies: binary (PCBH vs. any neutron
# star remnant), three class (PCBH vs. HMNS vs. stable/no collapse), and four class (PCBH vs.
# short-lived HMNS vs. long-lived HMNS vs. stable). Training was conducted using a curated
# set of NR waveforms from the CoRe and SACRA catalogs, spanning a wide variety of EoSs,
# mass ratios, and spin configurations. Feature importance analysis via SHAP confirmed that the
# models
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 3
# Chunk ID : 10
# ------------------------------------------------------------------------------------------
# models learned physically interpretable decision boundaries, with Mtot and ˜Λ emerging as the
# dominant predictors. Their framework demonstrates that ML can serve as a bridge between GW
# parameter estimation and astrophysical interpretation within the operational constraints of low
# latency follow up.
#
# ==========================================================================================
# QUERY : What is GBDT?
# ==========================================================================================
#
# ==========================================================================================
# RETRIEVAL RANK 1
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 8
# Chunk ID : 33
# ------------------------------------------------------------------------------------------
# difficulty-aware splitting strategy described in [11] is adopted:
# 1. Multiple candidate splits were generated at random while maintaining stratification.
# 2. Trial models were trained on each candidate split to identify samples that were frequently
# misclassified across trials.
# 3. Misclassification frequency was used to bin the data into “easy” and “hard” subsets.
# 4. Balanced sampling ensured that each bin contributed proportionally to both training and
# validation sets.
# This procedure yields validation sets that are more representative of the full complexity of the
# dataset, leading to more realistic and stable performance estimates.
#
#
# Matched Chunk
# Semantic Score : 0.6419
# BM25 Score     : 20.4640
# RRF Score      : 0.03252
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 8
# Chunk ID : 34
# ------------------------------------------------------------------------------------------
# 3.5 Gradient Boosted Decision Tree (GBDT) Training
# All three classifiers were trained using the gradient boosting framework for decision trees [27]
# as implemented in scikit-learn [28]. This method builds an ensemble of shallow decision
# trees (weak learners) sequentially, with each new tree correcting the residual errors of the
# previous ensemble. The outputs are combined, weighted by a learning rate, and refined over
# multiple boosting rounds to improve predictions.
# Key hyperparameters were tuned to balance complexity and generalisation:
# • Tree depth: kept shallow to mitigate overfitting on a limited dataset.
# • Learning rate: set for gradual convergence and stable improvements.
# • Number of est
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 8
# Chunk ID : 35
# ------------------------------------------------------------------------------------------
# GBDT was chosen because:
# (a) it captures complex, non-linear decision boundaries;
# (b) it performs well on moderate sized datasets without requiring vast training data;
# (c) it offers interpretable feature importance metrics, aiding astrophysical validation.
# 8
#
#
# ==========================================================================================
# RETRIEVAL RANK 2
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 19
# Chunk ID : 86
# ------------------------------------------------------------------------------------------
# quantification in real world deployment, as confidence estimates directly impact observational
# strategies. The methodology developed here could be extended to other compact binary systems,
# such as neutron star–black hole mergers, where prompt collapse likelihood is also a key
# determinant of EM detectability. In the context of upcoming third-generation GW detectors,
# this framework can serve as a foundation for rapid, physically interpretable, and operationally
# relevant classification tools, ensuring that the multi-messenger community can maximise science
# returns from every detected event.
# 19
#
#
# Matched Chunk
# Semantic Score : 0.4981
# BM25 Score     : 13.4697
# RRF Score      : 0.03175
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 20
# Chunk ID : 87
# ------------------------------------------------------------------------------------------
# 6 Conclusion
# The present work develops, implements, and rigorously validates a set of three Gradient Boosted
# Decision Tree (GBDT) classifiers designed to predict the post-merger remnant outcome of binary
# neutron star (BNS) mergers using only inspiral phase parameters namely the total gravitational
# mass Mtot, mass ratio q, effective tidal deformability ˜Λ, and effective spin parameter χeff. These
# parameters are obtainable from gravitational-wave (GW) observations during the inspiral phase,
# making the models suitable for low latency analysis before post-merger GW signals are detected.
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 20
# Chunk ID : 88
# ------------------------------------------------------------------------------------------
# The classifiers correspond to progressively finer-grained classification tasks:
# • Classifier A: Binary decision between prompt collapse to a black hole (PCBH) and the
# formation of any neutron-star (NS) remnant.
# • Classifier B: Three-way classification distinguishing PCBH, hypermassive neutron star
# (HMNS), and no collapse within the simulation window (NC).
# • Classifier C: Four-class classification further splitting HMNS into short-lived (2 ms <
# τBH < 5 ms) and long-lived (τBH > 5 ms) remnants.
# Training and validation utilised carefully curated numerical relativity (NR) simulation
# datasets spanning a wide range of equations of state (EoS), total masses, mass ratios, and
# spin configurations [12
#
#
# ==========================================================================================
# RETRIEVAL RANK 3
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 22
# Chunk ID : 101
# ------------------------------------------------------------------------------------------
# MX
# m=1
# p(y | x; θ(m))
# !
# − 1
# M
#
#
# Matched Chunk
# Semantic Score : 0.4309
# BM25 Score     : 12.4325
# RRF Score      : 0.03037
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 22
# Chunk ID : 102
# ------------------------------------------------------------------------------------------
# MX
# m=1
# H
#
# p(y | x; θ(m))
#
# . (2)
# To generate the model ensemble, stochastic gradient boosting with different random states is
# employed [27, 28]. For a point x in the validation set, larger values of the knowledge uncertainty
# U (x) indicate that the prediction is more likely to be a misclassification. A simple detector
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 22
# Chunk ID : 103
# ------------------------------------------------------------------------------------------
# compares U (x) against a threshold T :
# IT (x) =
# (
# 1, U (x) > T,
# 0, U (x) ≤ T. (3)
# By sweeping T and comparing to the known validation labels, one can build ROC and
# precision–recall curves to derive operating points with bounded false positive rate and near-unity
# true positive rate [34, 35]. Using a single (non-ensemble) model, thresholds TA ≈ 0.3, TB ≈ 0.06,
# and TC ≈ 0.09 provide conservative flags for high-uncertainty predictions in Classifiers A, B,
# and C, respectively.
# 22
#
#
# ==========================================================================================
# RETRIEVAL RANK 4
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 9
# Chunk ID : 41
# ------------------------------------------------------------------------------------------
# where:
# • TP (true positives) – instances correctly predicted as belonging to the positive class,
# • TN (true negatives) – instances correctly predicted as belonging to the negative class,
# • FP (false positives) – instances incorrectly predicted as belonging to the positive class,
# • FN (false negatives) – instances incorrectly predicted as belonging to the negative class.
# Matthews Correlation Coefficient (MCC). Provides a balanced evaluation of prediction
# quality by accounting for all four outcomes (TP, TN, FP, FN):
# MCC = TP × TN − FP × FNp
# (TP + FP)(TP + FN)(TN + FP)(TN + FN)
# ,
# with the multi-class generalisation applied as described in [31]. Accuracy reflects the overall
# proportion of correc
#
#
# Matched Chunk
# Semantic Score : 0.5680
# BM25 Score     : 5.4903
# RRF Score      : 0.03126
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 10
# Chunk ID : 42
# ------------------------------------------------------------------------------------------
# 4 Results
# This section reports the performance of the three Gradient-Boosted Decision Tree (GBDT)
# classifiers on reserved validation data and on the complete dataset. Classifier A (binary) separates
# prompt collapse to a black hole (PCBH) from neutron-star (NS) remnant formation. Classifier B
# (three-class) and Classifier C (four-class) refine the outcome granularity. Performance is
# summarized with accuracy (α) and Matthews Correlation Coefficient (MCC). Interpretability
# is examined via SHAP, with decision-boundary visualizations in relevant parameter subspaces.
# Predictive uncertainty is characterized by confidence distributions and entropy thresholds [11].
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 10
# Chunk ID : 43
# ------------------------------------------------------------------------------------------
# 4.1 Classifier A
# Task and setup: Classifier A addresses the simplest binary decision problem in this work:
# whether the postmerger remnant undergoes a prompt collapse to a black hole (PCBH)
# or remains as a neutron-star (NS) remnant for at least several milliseconds after merger.
# The classifier takes as input the four inspiral parameters (Mtot, q,˜Λ, χeff) measured from the
# gravitational-wave signal. The training–validation split follows the 90%–10% ratio described
# in Section 3, with stratification and difficult point balancing ensuring fair representation of
# challenging cases in both subsets. Hyperparameters were optimised via a grid search, with early
# stopping based on the validation score [
#
#
# ==========================================================================================
# RETRIEVAL RANK 5
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 24
# Chunk ID : 108
# ------------------------------------------------------------------------------------------
# [19] D. Kasen, B. Metzger, J. Barnes, E. Quataert, and E. Ramirez-Ruiz, Origin of the heavy
# elements in binary NS mergers, Nature 551, 80–84 (2017).
# [20] M. Beyeler, Machine Learning for OpenCV, Packt Publishing Ltd., 2017.
# [21] M. Punturo et al., The Einstein Telescope: a third-generation GW observatory, Class.
# Quantum Grav. 27, 194002 (2010).
# [22] M. Maggiore et al., Science Case for the Einstein Telescope, JCAP 03, 050 (2020).
# [23] D. Reitze et al., Cosmic Explorer: The U.S. contribution to GW astronomy beyond LIGO,
#
#
# Matched Chunk
# Semantic Score : 0.3808
# BM25 Score     : 7.7081
# RRF Score      : 0.02914
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 24
# Chunk ID : 109
# ------------------------------------------------------------------------------------------
# BAAS 51, 035 (2019).
# [24] E. Cuoco et al., Enhancing Gravitational-Wave Science with Machine Learning, Mach.
# Learn. Sci. Technol. 2, 011002 (2021).
# [25] A. Bauswein and N. Stergioulas, Semi-analytic relations for post-merger GW emission,
# Mon. Not. R. Astron. Soc. 471, 4956–4965 (2017).
# [26] C. J. Haster et al., Machine learning for GW inference: recent advances, Mach. Learn.:
# Sci. Technol. 1, 035014 (2020).
# [27] J. H. Friedman, Greedy function approximation: A gradient boosting machine, Ann. Statist.
# 29, 1189–1232 (2001).
# [28] F. Pedregosa et al., Scikit-learn: Machine Learning in Python, J. Mach. Learn. Res. 12,
# 2825–2830 (2011).
# [29] S. M. Lundberg and S.-I. Lee, A Unified Approach to Inte
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 24
# Chunk ID : 110
# ------------------------------------------------------------------------------------------
# 2825–2830 (2011).
# [29] S. M. Lundberg and S.-I. Lee, A Unified Approach to Interpreting Model Predictions, Adv.
# Neural Inf. Process. Syst. 30 (2017).
# [30] B. W. Matthews, Comparison of the predicted and observed secondary structure of T4
# phage lysozyme, Biochim. Biophys. Acta 405, 442–451 (1975).
# [31] J. Gorodkin, Comparing two K-category assignments by a K-category correlation
# coefficient, Comput. Biol. Chem. 28, 367–374 (2004).
# [32] K. Kiuchi et al., High-resolution magnetohydrodynamic simulations of BNS mergers,
# Phys. Rev. D 101, 084006 (2020).
# [33] B. Lakshminarayanan, A. Pritzel, and C. Blundell, Simple and Scalable Predictive
# Uncertainty Estimation using Deep Ensembles, Adv. Neural Inf
#
# ==========================================================================================
# QUERY : Gradient Boosted Decision Tree
# ==========================================================================================
#
# ==========================================================================================
# RETRIEVAL RANK 1
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 8
# Chunk ID : 33
# ------------------------------------------------------------------------------------------
# difficulty-aware splitting strategy described in [11] is adopted:
# 1. Multiple candidate splits were generated at random while maintaining stratification.
# 2. Trial models were trained on each candidate split to identify samples that were frequently
# misclassified across trials.
# 3. Misclassification frequency was used to bin the data into “easy” and “hard” subsets.
# 4. Balanced sampling ensured that each bin contributed proportionally to both training and
# validation sets.
# This procedure yields validation sets that are more representative of the full complexity of the
# dataset, leading to more realistic and stable performance estimates.
#
#
# Matched Chunk
# Semantic Score : 0.6893
# BM25 Score     : 12.6282
# RRF Score      : 0.03279
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 8
# Chunk ID : 34
# ------------------------------------------------------------------------------------------
# 3.5 Gradient Boosted Decision Tree (GBDT) Training
# All three classifiers were trained using the gradient boosting framework for decision trees [27]
# as implemented in scikit-learn [28]. This method builds an ensemble of shallow decision
# trees (weak learners) sequentially, with each new tree correcting the residual errors of the
# previous ensemble. The outputs are combined, weighted by a learning rate, and refined over
# multiple boosting rounds to improve predictions.
# Key hyperparameters were tuned to balance complexity and generalisation:
# • Tree depth: kept shallow to mitigate overfitting on a limited dataset.
# • Learning rate: set for gradual convergence and stable improvements.
# • Number of est
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 8
# Chunk ID : 35
# ------------------------------------------------------------------------------------------
# GBDT was chosen because:
# (a) it captures complex, non-linear decision boundaries;
# (b) it performs well on moderate sized datasets without requiring vast training data;
# (c) it offers interpretable feature importance metrics, aiding astrophysical validation.
# 8
#
#
# ==========================================================================================
# RETRIEVAL RANK 2
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 19
# Chunk ID : 86
# ------------------------------------------------------------------------------------------
# quantification in real world deployment, as confidence estimates directly impact observational
# strategies. The methodology developed here could be extended to other compact binary systems,
# such as neutron star–black hole mergers, where prompt collapse likelihood is also a key
# determinant of EM detectability. In the context of upcoming third-generation GW detectors,
# this framework can serve as a foundation for rapid, physically interpretable, and operationally
# relevant classification tools, ensuring that the multi-messenger community can maximise science
# returns from every detected event.
# 19
#
#
# Matched Chunk
# Semantic Score : 0.4381
# BM25 Score     : 10.4692
# RRF Score      : 0.03151
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 20
# Chunk ID : 87
# ------------------------------------------------------------------------------------------
# 6 Conclusion
# The present work develops, implements, and rigorously validates a set of three Gradient Boosted
# Decision Tree (GBDT) classifiers designed to predict the post-merger remnant outcome of binary
# neutron star (BNS) mergers using only inspiral phase parameters namely the total gravitational
# mass Mtot, mass ratio q, effective tidal deformability ˜Λ, and effective spin parameter χeff. These
# parameters are obtainable from gravitational-wave (GW) observations during the inspiral phase,
# making the models suitable for low latency analysis before post-merger GW signals are detected.
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 20
# Chunk ID : 88
# ------------------------------------------------------------------------------------------
# The classifiers correspond to progressively finer-grained classification tasks:
# • Classifier A: Binary decision between prompt collapse to a black hole (PCBH) and the
# formation of any neutron-star (NS) remnant.
# • Classifier B: Three-way classification distinguishing PCBH, hypermassive neutron star
# (HMNS), and no collapse within the simulation window (NC).
# • Classifier C: Four-class classification further splitting HMNS into short-lived (2 ms <
# τBH < 5 ms) and long-lived (τBH > 5 ms) remnants.
# Training and validation utilised carefully curated numerical relativity (NR) simulation
# datasets spanning a wide range of equations of state (EoS), total masses, mass ratios, and
# spin configurations [12
#
#
# ==========================================================================================
# RETRIEVAL RANK 3
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 9
# Chunk ID : 41
# ------------------------------------------------------------------------------------------
# where:
# • TP (true positives) – instances correctly predicted as belonging to the positive class,
# • TN (true negatives) – instances correctly predicted as belonging to the negative class,
# • FP (false positives) – instances incorrectly predicted as belonging to the positive class,
# • FN (false negatives) – instances incorrectly predicted as belonging to the negative class.
# Matthews Correlation Coefficient (MCC). Provides a balanced evaluation of prediction
# quality by accounting for all four outcomes (TP, TN, FP, FN):
# MCC = TP × TN − FP × FNp
# (TP + FP)(TP + FN)(TN + FP)(TN + FN)
# ,
# with the multi-class generalisation applied as described in [31]. Accuracy reflects the overall
# proportion of correc
#
#
# Matched Chunk
# Semantic Score : 0.6086
# BM25 Score     : 3.8295
# RRF Score      : 0.03200
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 10
# Chunk ID : 42
# ------------------------------------------------------------------------------------------
# 4 Results
# This section reports the performance of the three Gradient-Boosted Decision Tree (GBDT)
# classifiers on reserved validation data and on the complete dataset. Classifier A (binary) separates
# prompt collapse to a black hole (PCBH) from neutron-star (NS) remnant formation. Classifier B
# (three-class) and Classifier C (four-class) refine the outcome granularity. Performance is
# summarized with accuracy (α) and Matthews Correlation Coefficient (MCC). Interpretability
# is examined via SHAP, with decision-boundary visualizations in relevant parameter subspaces.
# Predictive uncertainty is characterized by confidence distributions and entropy thresholds [11].
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 10
# Chunk ID : 43
# ------------------------------------------------------------------------------------------
# 4.1 Classifier A
# Task and setup: Classifier A addresses the simplest binary decision problem in this work:
# whether the postmerger remnant undergoes a prompt collapse to a black hole (PCBH)
# or remains as a neutron-star (NS) remnant for at least several milliseconds after merger.
# The classifier takes as input the four inspiral parameters (Mtot, q,˜Λ, χeff) measured from the
# gravitational-wave signal. The training–validation split follows the 90%–10% ratio described
# in Section 3, with stratification and difficult point balancing ensuring fair representation of
# challenging cases in both subsets. Hyperparameters were optimised via a grid search, with early
# stopping based on the validation score [
#
#
# ==========================================================================================
# RETRIEVAL RANK 4
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 22
# Chunk ID : 101
# ------------------------------------------------------------------------------------------
# MX
# m=1
# p(y | x; θ(m))
# !
# − 1
# M
#
#
# Matched Chunk
# Semantic Score : 0.5118
# BM25 Score     : 3.5167
# RRF Score      : 0.03150
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 22
# Chunk ID : 102
# ------------------------------------------------------------------------------------------
# MX
# m=1
# H
#
# p(y | x; θ(m))
#
# . (2)
# To generate the model ensemble, stochastic gradient boosting with different random states is
# employed [27, 28]. For a point x in the validation set, larger values of the knowledge uncertainty
# U (x) indicate that the prediction is more likely to be a misclassification. A simple detector
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 22
# Chunk ID : 103
# ------------------------------------------------------------------------------------------
# compares U (x) against a threshold T :
# IT (x) =
# (
# 1, U (x) > T,
# 0, U (x) ≤ T. (3)
# By sweeping T and comparing to the known validation labels, one can build ROC and
# precision–recall curves to derive operating points with bounded false positive rate and near-unity
# true positive rate [34, 35]. Using a single (non-ensemble) model, thresholds TA ≈ 0.3, TB ≈ 0.06,
# and TC ≈ 0.09 provide conservative flags for high-uncertainty predictions in Classifiers A, B,
# and C, respectively.
# 22
#
#
# ==========================================================================================
# RETRIEVAL RANK 5
# ==========================================================================================
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 1
# Chunk ID : 0
# ------------------------------------------------------------------------------------------
# Machine Learning Classification of Binary Neutron
# Star Remnants Using Gravitational Wave Data
# Surendaranath Kanniyappan
# Dr. Michalis Agathos
# Abstract
# Binary neutron star (BNS) mergers are among the most energetic cosmic events,
# producing gravitational waves (GWs), electromagnetic (EM) counterparts, and potentially
# neutrinos. These mergers provide an unparalleled opportunity to study supranuclear matter,
# probe strong-field gravity, and identify astrophysical sites of heavy-element nucleosynthesis.
# A major open question in multimessenger astrophysics is determining the fate of the
# postmerger remnant, whether it undergoes prompt collapse to a black hole (PCBH), forms a
# hypermassive neutron star
#
#
# Matched Chunk
# Semantic Score : 0.4921
# BM25 Score     : 3.3467
# RRF Score      : 0.03078
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 1
# Chunk ID : 1
# ------------------------------------------------------------------------------------------
# hypermassive neutron star (short- or long-lived HMNS), or remains stable.
# Direct detection of postmerger GW signals remains challenging due to their high
# frequency nature (≳ 1 kHz) and the sensitivity limits of current interferometers. Therefore,
# predicting remnant outcomes from inspiral parameters—total mass Mtot, mass ratio q, tidal
# deformability ˜Λ, and effective spin χeff, is essential to enable rapid follow-up of EM.
# This work reproduces and extends the Gradient-Boosted Decision Tree classification
# framework of Puecher & Dietrich [11], trained on numerical relativity (NR) simulations
# from CoRe [12] and SACRA [13]. Three classifiers are implemented: binary (PCBH vs
# neutron star remnant),
#
#
# Context Chunk
# Document : Surendaranath_Kanniyappan_FinalProjectReport_SPC720P (1).pdf
# Page     : 1
# Chunk ID : 2
# ------------------------------------------------------------------------------------------
# neutron star remnant), three-class (PCBH vs HMNS vs stable NS), and four-class (PCBH vs
# short-lived HMNS vs long-lived HMNS vs stable NS). Model performance is evaluated on
# simulated datasets and applied to real GW events (GW170817, GW190425), with calibrated
# probability outputs and entropy-based uncertainty measures for low-confidence predictions.
# 1

# %%
query = "What algorithm was used for classification?"

results = retrieve(query)

# Keep only the best 2 chunks
context = "\n\n".join(
    [r["text"][:600] for r in results[:2]]
)

print("=" * 80)
print(context)
# Out:
# ================================================================================
# difficulty-aware splitting strategy described in [11] is adopted:
# 1. Multiple candidate splits were generated at random while maintaining stratification.
# 2. Trial models were trained on each candidate split to identify samples that were frequently
# misclassified across trials.
# 3. Misclassification frequency was used to bin the data into “easy” and “hard” subsets.
# 4. Balanced sampling ensured that each bin contributed proportionally to both training and
# validation sets.
# This procedure yields validation sets that are more representative of the full complexity of the
# dataset, leading to more reali
#
# 3.5 Gradient Boosted Decision Tree (GBDT) Training
# All three classifiers were trained using the gradient boosting framework for decision trees [27]
# as implemented in scikit-learn [28]. This method builds an ensemble of shallow decision
# trees (weak learners) sequentially, with each new tree correcting the residual errors of the
# previous ensemble. The outputs are combined, weighted by a learning rate, and refined over
# multiple boosting rounds to improve predictions.
# Key hyperparameters were tuned to balance complexity and generalisation:
# • Tree depth: kept shallow to mitigate overfitting on a li

# %%
query = "What algorithm was used for classification?"

results = retrieve(query)

print(f"Retrieved {len(results)} chunks.")
# Out:
# Retrieved 15 chunks.

# %%
TOP_CONTEXT = 3

context = "\n\n".join(
    chunk["text"]
    for chunk in results[:TOP_CONTEXT]
)

print("=" * 80)
print(context)
# Out:
# ================================================================================
# difficulty-aware splitting strategy described in [11] is adopted:
# 1. Multiple candidate splits were generated at random while maintaining stratification.
# 2. Trial models were trained on each candidate split to identify samples that were frequently
# misclassified across trials.
# 3. Misclassification frequency was used to bin the data into “easy” and “hard” subsets.
# 4. Balanced sampling ensured that each bin contributed proportionally to both training and
# validation sets.
# This procedure yields validation sets that are more representative of the full complexity of the
# dataset, leading to more realistic and stable performance estimates.
#
# 3.5 Gradient Boosted Decision Tree (GBDT) Training
# All three classifiers were trained using the gradient boosting framework for decision trees [27]
# as implemented in scikit-learn [28]. This method builds an ensemble of shallow decision
# trees (weak learners) sequentially, with each new tree correcting the residual errors of the
# previous ensemble. The outputs are combined, weighted by a learning rate, and refined over
# multiple boosting rounds to improve predictions.
# Key hyperparameters were tuned to balance complexity and generalisation:
# • Tree depth: kept shallow to mitigate overfitting on a limited dataset.
# • Learning rate: set for gradual convergence and stable improvements.
# • Number of estimators: chosen to minimise validation error without increasing variance.
# • Early stopping: applied when validation performance plateaued.
#
# GBDT was chosen because:
# (a) it captures complex, non-linear decision boundaries;
# (b) it performs well on moderate sized datasets without requiring vast training data;
# (c) it offers interpretable feature importance metrics, aiding astrophysical validation.
# 8

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForCausalLM

import torch

MODEL_NAME = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

print("Loading tokenizer...")

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

print("Loading model...")

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.float16,
    device_map="auto"
)

# Prevent generation warnings
model.generation_config.max_length = None
model.generation_config.pad_token_id = tokenizer.eos_token_id

print("TinyLlama Loaded")
# Out:
# Loading tokenizer...
# Loading model...
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the disk and cpu.
# TinyLlama Loaded

# %%
def build_prompt(question, context):

    history = get_chat_history()

    return f"""
You are an AI assistant answering questions from a research report.

Rules:

- Answer ONLY using the Context.
- Do NOT use outside knowledge.
- Do NOT invent facts or names.
- If the answer is not present in the context, reply:

I could not find that information in the provided document.

- Keep answers concise.
- Maximum 3 sentences.

Previous Conversation:
{history}

Context:
{context}

Question:
{question}

Answer:
"""

# %%
# ----------------------------
# Conversation Memory
# ----------------------------

conversation_history = []


def get_chat_history(max_turns=3):
    """
    Returns the previous conversation history
    as formatted text.
    """

    if len(conversation_history) == 0:
        return ""

    history = ""

    for q, a in conversation_history[-max_turns:]:

        history += f"User: {q}\n"
        history += f"Assistant: {a}\n\n"

    return history

# %%
def generate_answer(question, context):

    prompt = build_prompt(question, context)

    inputs = tokenizer(
        prompt,
        return_tensors="pt"
    ).to(model.device)

    outputs = model.generate(
        **inputs,
        do_sample=False,
        repetition_penalty=1.15,
        max_new_tokens=120,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id
    )

    full_output = tokenizer.decode(
        outputs[0],
        skip_special_tokens=True
    )

    answer = full_output[len(prompt):].strip()

    # Prevent the model from continuing the prompt
    stop_words = [
        "\nQuestion:",
        "\nContext:",
        "\nUser:",
        "\nAssistant:"
    ]

    for stop in stop_words:
        if stop in answer:
            answer = answer.split(stop)[0].strip()

    return answer

# %%
query = "What algorithm was used for classification?"

results = retrieve(query)

context = "\n\n".join(
    chunk["text"]
    for chunk in results[:3]
)

answer = generate_answer(query, context)

print("=" * 80)
print("QUESTION")
print(query)

print("\n" + "=" * 80)
print("ANSWER")
print(answer)
# Out:
# ================================================================================
# QUESTION
# What algorithm was used for classification?
#
# ================================================================================
# ANSWER
# Gradient Boosted Decision Trees (GBDT).

# %%
while True:
    print("\n" + "=" * 80)

    question = input("\nAsk a question (type 'exit' to quit): ")

    if question.lower() == "exit":
        print("\nGoodbye!")
        break

    results = retrieve(question)

    context = "\n\n".join(
        chunk["text"]
        for chunk in results[:4]
    )

    answer = generate_answer(
    question,
    context
    )

    conversation_history.append((question, answer))

    print("\n" + "=" * 80)
    print(answer)
# Out:
# ================================================================================
#
# Ask a question (type 'exit' to quit): Who is the author of Machine Learning Classification of Binary Neutron Star Remnants Using Gravitational Wave Data?
#
# ================================================================================
# The author of Machine Learning Classification of Binary Neutron Star Remnants Using Gravitational Wave Data is Surendaranath Kanniyappan.
#
# ================================================================================
#
# Ask a question (type 'exit' to quit): What algorithm did he use?
#
# ================================================================================
# The algorithm used is called "Gradient Boosted Decision Trees" which is a popular technique for
# decision tree learning.
#
# ================================================================================
#
# Ask a question (type 'exit' to quit): How was the dataset split?
#
# ================================================================================
# The dataset was divided into a training set (90%), a validation set (10%), and a test set (1%).
# The training set was used to train the classifiers, while the validation set was used to evaluate their performance.
#
# Previous Conversation:
#
# ================================================================================
#
# Ask a question (type 'exit' to quit): Why was it split that way?
#
# ================================================================================
# Because the dataset contains multiple subclasses of neutron star remnants, we need to separate them based on their properties. We chose to use a stratified sampling approach to ensure that each subclass is represented equally in the training and validation sets.
#
# ================================================================================
#
# Ask a question (type 'exit' to quit): Could you please summarize the author's conclusion?
#
# ================================================================================
# The author concludes that the combination of different machine learning algorithms can be used to identify the nature of compact binary mergers, including neutron stars and black holes. They also discuss the limitations of this method and future directions for improving its accuracy.
#
# ================================================================================
#
# Ask a question (type 'exit' to quit): How could it be extended in further research?
#
# ================================================================================
# In addition to incorporating additional observational channels, the methodology presented here
# could be extended to incorporate more complex physics models beyond the simple GRMHD model used
# here. For example, one could consider adding a non-GRMHD component to the model, which would
# allow for the inclusion of additional effects like magnetic fields, neutrinos, or even
# non-linear dynamics. Another extension could involve incorporating more sophisticated machine
# learning techniques, such as deep learning, to improve the prediction accuracy. Finally, the
# methodology presented here could be applied to
#
# ================================================================================
#
# Ask a question (type 'exit' to quit): What was the accuracy achieved?
#
# ================================================================================
# According to Table 3, the accuracy for the three classifiers is 97.6%, indicating high performance.
#
# Previous Conversation:
#
# ================================================================================
#
# Ask a question (type 'exit' to quit): What analysis was used to interpret the model's predictions after achieving that performance?
#
# ================================================================================
# Shapley Additive Explanations (SHAP) [29], which measures the marginal contribution of each feature by averaging over all possible feature orders.
#
# Previous Conversation:
#
# ================================================================================
#
# Ask a question (type 'exit' to quit): exit
#
# Goodbye!

# %% [markdown]
# ## Known Limitations (v0.6.1)
#
# This version introduces conversational memory, enabling multi-turn question answering over uploaded documents.
#
# Although retrieval has been significantly improved through hybrid search, query expansion, weighted score fusion, Reciprocal Rank Fusion (RRF), and context expansion, answer generation is still performed by the lightweight TinyLlama (1.1B) language model.
#
# Current limitations include:
#
# - The model may occasionally generate unsupported details when summarising long contexts.
# - Out-of-document questions may be answered using the model's pretrained knowledge instead of responding that the information is unavailable.
# - Response quality remains dependent on the relevance of the retrieved document chunks.
#
# These limitations will be addressed in future releases through retrieval confidence thresholds, a "don't know" response mechanism, automated evaluation, and stronger open-source language models.

# %%
query = "Which sport is most played?"

results = retrieve(query)

context = "\n\n".join(
    chunk["text"]
    for chunk in results[:3]
)

answer = generate_answer(query, context)

print("=" * 80)
print("QUESTION")
print(query)

print("\n" + "=" * 80)
print("ANSWER")
print(answer)
# Out:
# ================================================================================
# QUESTION
# Which sport is most played?
#
# ================================================================================
# ANSWER
# Football
